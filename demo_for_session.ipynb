# %% [markdown]
# ## Let us first do all the imports required

# %%
from Cosmika.qubit import QubitState,QuantumStateError
from Cosmika.gate_simulator import GateSimulator,CircuitSimulator,GateSimulatorError

from Cosmika.gate_simulator.visualization import state_table,histogram_text
from Cosmika import gates as G
import pytest
# Out:
# Running cells with '.cosmika (3.11.5) (Python 3.11.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/USER/Downloads/Cosmika/.cosmika/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
